# %%
import pandas as pd
from sklearn.metrics import accuracy_score 
data={  
       "bp":[120,140,130,150,110],
       "sugar":[5,6,7,8,9],
       "gender":["m","f","m","m","f"],
       "cholesterol":[180,200,220,240,260],
       "heart_disease":[0,1,1,1,0]
     }
df=pd.DataFrame(data)
print(df)
df['gender']=df['gender'].map({'m':0,'f':1})
x=df[['bp','sugar','gender','cholesterol']]
y=df["heart_disease"]
acc=accuracy_score (y,y)
print("acc:",acc)
# Out:
#     bp  sugar gender  cholesterol  heart_disease
# 0  120      5      m          180              0
# 1  140      6      f          200              1
# 2  130      7      m          220              1
# 3  150      8      m          240              1
# 4  110      9      f          260              0
# acc: 1.0

# %%
import pandas as pd
from sklearn.metrics import accuracy_score   
data = {  
    "bp": [120, 140, 130, 150, 110],
    "sugar": [5, 6, 7, 8, 9],
    "gender": ["m", "f", "m", "m", "f"],
    "cholesterol": [180, 200, 220, 240, 260],
    "heart_disease": [0, 1, 1, 1, 0]
}

df = pd.DataFrame(data)
print(df)

df["gender"] = df["gender"].map({"m": 0, "f": 1})

X = df[["bp", "sugar", "gender", "cholesterol"]]
y = df["heart_disease"]

accuracy = accuracy_score(y, y)
print("accuracy:", accuracy)
# Out:
#     bp  sugar gender  cholesterol  heart_disease
# 0  120      5      m          180              0
# 1  140      6      f          200              1
# 2  130      7      m          220              1
# 3  150      8      m          240              1
# 4  110      9      f          260              0
# accuracy: 1.0

# %%
from nltk.util import ngrams

n = 2
s = "sdovinsvisv"

unigrams = ngrams(s, n)

for item in unigrams:
    print(item)
# Out:
# ('s', 'd')
# ('d', 'o')
# ('o', 'v')
# ('v', 'i')
# ('i', 'n')
# ('n', 's')
# ('s', 'v')
# ('v', 'i')
# ('i', 's')
# ('s', 'v')

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(5,3),
                  index=['a','b','c','d','e'],
                  columns=['ban','mad','delhi'])
print(df)

df = df.reindex(['a','b','c','d','e','f','g','h','i'])
print(df)

df1 = df['ban'].isnull()
print(df1)

df = df.fillna(method="fillna")
print(df)
# Out:
#         ban       mad     delhi
# a  0.350686  0.372406  0.697646
# b  0.706736  0.530968  0.473305
# c  0.545813  0.725777  0.638364
# d  0.492886  0.319741  0.038734
# e  0.567136  0.584427  0.454220
#         ban       mad     delhi
# a  0.350686  0.372406  0.697646
# b  0.706736  0.530968  0.473305
# c  0.545813  0.725777  0.638364
# d  0.492886  0.319741  0.038734
# e  0.567136  0.584427  0.454220
# f       NaN       NaN       NaN
# g       NaN       NaN       NaN
# h       NaN       NaN       NaN
# i       NaN       NaN       NaN
# a    False
# b    False
# c    False
# d    False
# e    False
# f     True
# g     True
# h     True
# i     True
# Name: ban, dtype: bool
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 15
#      12 df1 = df['ban'].isnull()
#      13 print(df1)
# ---> 15 df = df.fillna(method="fillna")
#      16 print(df)
#
# ...
